# %% [markdown]
# # 01 · Train (or load) the β-VAE prior
#
# The training loop is given. You implement the **reparameterisation trick** in
# `models/vae.py`, then choose β / latent dim / epochs. Short on GPU time? Load
# the provided checkpoint instead.

# %%
import jax
from mrigen.train_vae import train, load_model

# %% [markdown]
# ### Option A — train

# %%
# model = train('../data/processed', latent_dim=128, beta=1.0, epochs=50,
#               out='../checkpoints/vae_128.eqx')

# %% [markdown]
# ### Option B — load the provided checkpoint

# %%
vae = load_model('../checkpoints/vae_128.eqx', latent_dim=128)
print('loaded VAE, latent_dim =', vae.latent_dim)
