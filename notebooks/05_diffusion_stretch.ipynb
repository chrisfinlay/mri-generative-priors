# %% [markdown]
# # 05 · Diffusion prior + posterior sampling  *(STRETCH)*
#
# Optional. Only after the VAE pipeline works end to end. Train a small score
# model (`models/diffusion.py`) and reconstruct with DPS
# (`recon/diffusion_dps.py`). Both ship as skeletons — see section 9 of the
# codebase plan.

# %%
# from mrigen.recon.diffusion_dps import dps_reconstruct  # stretch goal
